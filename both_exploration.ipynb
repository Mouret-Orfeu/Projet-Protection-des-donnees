# %%
import pandas as pd

# %%
df_p_normal = pd.read_csv("physical/phy_norm.csv",sep=";")
df_p_attack_1 = pd.read_csv("physical/phy_att_1.csv",sep=";")
df_p_attack_2 = pd.read_csv("physical/phy_att_2.csv",sep=";")
df_p_attack_3 = pd.read_csv("physical/phy_att_3.csv",sep=";")
df_p_attack_4 = pd.read_csv("physical/phy_att_4.csv")

# %%
df_n_normal = pd.read_csv("network/normal.csv")
df_n_attack_1 = pd.read_csv("network/attack_1.csv")
df_n_attack_2 = pd.read_csv("network/attack_2.csv")
df_n_attack_3 = pd.read_csv("network/attack_3.csv")
df_n_attack_4 = pd.read_csv("network/attack_4.csv")

# %%
df_n_attack_1.head(20)
# Out:
#                           Time              mac_s              mac_d  \
# 0   2021-04-09 18:23:28.385003  74:46:a0:bd:a7:1b  0a:fe:ec:47:74:fb
# 1   2021-04-09 18:23:28.385005  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
# 2   2021-04-09 18:23:28.385006  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 3   2021-04-09 18:23:28.385484  0a:fe:ec:47:74:fb  74:46:a0:bd:a7:1b
# 4   2021-04-09 18:23:28.385486  fa:00:bc:90:d7:fa  74:46:a0:bd:a7:1b
# 5   2021-04-09 18:23:28.385500  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
# 6   2021-04-09 18:23:28.386355  00:80:f4:03:fb:12  74:46:a0:bd:a7:1b
# 7   2021-04-09 18:23:28.387961  74:46:a0:bd:a7:1b  0a:fe:ec:47:74:fb
# 8   2021-04-09 18:23:28.387964  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
# 9   2021-04-09 18:23:28.387965  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 10  2021-04-09 18:23:28.388440  0a:fe:ec:47:74:fb  74:46:a0:bd:a7:1b
# 11  2021-04-09 18:23:28.388442  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
# 12  2021-04-09 18:23:28.388443  fa:00:bc:90:d7:fa  74:46:a0:bd:a7:1b
# ...

# %%
from datetime import *

# %%
def transform_time(string):
    try:
        d = datetime.strptime(string, '%Y-%m-%d %H:%M:%S.%f')
    except:
        
    return str(d.hour)+":"+str(d.minute)

# %%
df_n_attack_1["Time"].map(transform_time).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Nikko\Documents\programmation\Ecole\2ème_année\protection des données\Projet-Protection-des-donnes\both_exploration.ipynb Cellule 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Nikko/Documents/programmation/Ecole/2%C3%A8me_ann%C3%A9e/protection%20des%20donn%C3%A9es/Projet-Protection-des-donnes/both_exploration.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> df_n_attack_1["Time"].map(transform_time)
#
# File c:\Users\Nikko\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
# ...

# %%
pd.unique(df_p_attack_1["Time"])
for k in pd.unique(df_p_attack_1["Time"]):
    print(len(df_p_attack_1[df_p_attack_1["Time"]==k]))

# %%
df_p_attack_1.head()
# Out:
#                Time  Tank_1  Tank_2  Tank_3  Tank_4  Tank_5  Tank_6  Tank_7  \
# 0  09/04/2021 18:23       0       0       0       0       0       0       0
# 1  09/04/2021 18:23       0       0       0       0       0       0       0
# 2  09/04/2021 18:23       0       0       0       0       0       0       0
# 3  09/04/2021 18:23       0       0       0       0       0       0       0
# 4  09/04/2021 18:23       0       0       0       0       0       0       0
#
#    Tank_8  Pump_1  ...  Valv_15  Valv_16  Valv_17  Valv_18  Valv_19  Valv_20  \
# 0       0   False  ...    False    False    False    False    False    False
# 1       0   False  ...    False    False    False    False    False    False
# 2       0   False  ...    False    False    False    False    False    False
# 3       0   False  ...    False    False    False    False    False    False
# 4       0    True  ...    False    False    False    False    False    False
#
#    Valv_21  Valv_22  Label_n   Label
# ...

# %%
pd.unique(df_p_attack_1["Time"])
for k in pd.unique(df_p_attack_1["Time"]):
    print(len(df_p_attack_1[df_p_attack_1["Time"]==k]))
# Out:
# 32
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 48

# %%
new_df = df_p_attack_1[df_p_attack_1["Label_n"]!=0]
new_df.head(40)
# Out:
#                  Time  Tank_1  Tank_2  Tank_3  Tank_4  Tank_5  Tank_6  Tank_7  \
# 140  09/04/2021 18:25     922    1301     743     465     740      72       0
# 141  09/04/2021 18:25     906    1288     753     481     736      78       0
# 142  09/04/2021 18:25     894    1276     760     492     731      86       0
# 143  09/04/2021 18:25     878    1261     769     507     727      86       0
# 144  09/04/2021 18:25     865    1250     774     520     722      94       0
# 145  09/04/2021 18:25     850    1236     787     535     718      94       0
# 146  09/04/2021 18:25     839    1225     790     546     712     100       0
# 147  09/04/2021 18:25     823    1209     802     564     708     109       0
# 148  09/04/2021 18:25     810    1199     808     575     703     109       0
# 149  09/04/2021 18:25     795    1188     815     586     699     116       0
# 150  09/04/2021 18:25     782    1172     824     602     695     121       0
# ...
